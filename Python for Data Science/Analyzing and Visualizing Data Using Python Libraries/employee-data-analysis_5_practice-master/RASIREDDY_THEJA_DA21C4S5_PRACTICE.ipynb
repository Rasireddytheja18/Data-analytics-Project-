# %%
import pandas as pd

data = pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx')
data
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %% [markdown]
# ### Task - 1

# %%
emp_sal = data.groupby(by = ['Department'])['Annual Salary ($)'].sum()
emp_sal
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
import matplotlib.pyplot as plt

emp_sal.plot(kind='bar', color='skyblue')
                                           # To build bar chart
plt.title("Vertical Bar chart")            # Title name
plt.show()

# %% [markdown]
# ### Task - 2

# %%
dp_gn = data.groupby(by = ['Department','Gender'])['Gender'].count()
dp_gn
# Out:
# Department  Gender
# Finance     Female     2
#             Male      11
# HR          Female    11
#             Male       4
# IT          Female    10
#             Male      12
# Sales       Female     4
#             Male      16
# Name: Gender, dtype: int64

# %%
new_df = pd.DataFrame(dp_gn)
print(new_df)
# Out:
#                    Gender
# Department Gender
# Finance    Female       2
#            Male        11
# HR         Female      11
#            Male         4
# IT         Female      10
#            Male        12
# Sales      Female       4
#            Male        16

# %%
pd.crosstab(data.Department, data.Gender, rownames=['Department'], colnames=['Gender'])
# Out:
# Gender      Female  Male
# Department
# Finance          2    11
# HR              11     4
# IT              10    12
# Sales            4    16

# %%
dp_gn.plot(kind='barh', color='skyblue')
# Out:
# <Axes: ylabel='Department,Gender'>

# %% [markdown]
# ### Task - 3

# %%
work_exp = data[(data.Work_Experience == 0)]
work_exp
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 17            1027  Female         HR              28000   22                0
# 38            1047  Female      Sales              28000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
work_exp1 = data[(data.Work_Experience == 0) & (data.Department == 'IT')]
work_exp1
# Out:
# Empty DataFrame
# Columns: [Employee_Code , Gender, Department, Annual Salary ($), Age, Work_Experience]
# Index: []

# %% [markdown]
# ### Task - 4

# %%
emp_sal = data.groupby(by = ['Department'])['Annual Salary ($)'].sum()
emp_sal1 = pd.DataFrame(emp_sal)
print('Department wise the total Annual Salary:')
emp_sal1
# Out:
# Department wise the total Annual Salary:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
plt.pie(emp_sal.values, labels = emp_sal.index, autopct='%.2f %%')     # To create pie chart with percentage of each portion
plt.title("Pie Chart")                                            # Define Title 
plt.show()

# %% [markdown]
# ### Task - 5

# %%
## worng we to claculate count

# %%
import matplotlib.pyplot as plt

# Define age group bins from 25 to 50 with intervals of 5 years
age_bins = [25, 30, 35, 40, 45, 50]

# Plot the histogram

plt.hist(data['Age'], bins=age_bins, edgecolor='black')  # Replace 'data['Age']' with your actual column name
plt.title('Employee Count by Age Group')
plt.xlabel('Age')
plt.ylabel('Employee Count')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(data['Age'])
plt.show()

# %% [markdown]
# ### Task - 6

# %%
plt.scatter(data['Work_Experience'], data['Annual Salary ($)'])
plt.show()

# %% [markdown]
# ### Task - 7

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing department-wise salary information


sb.boxplot(x='Department', y='Annual Salary ($)', data=data)
plt.title('Department-wise Salary Spread')
plt.xlabel('Department')
plt.ylabel('Salary')

plt.show()
