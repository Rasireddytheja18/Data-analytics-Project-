# %%
import pandas as pd

# %%
import mysql.connector as sql

# %%
# task 1

# %%
conn=sql.connect(host='localhost',database='hr',user='root',password='root123')
if conn.is_connected:
    print('connection success')
# Out:
# connection success

# %%
df_hr=pd.read_sql_query('select country_name, region_name from countries join regions using (region_id)',conn)
# Out:
# C:\Users\Rasireddy Theja\AppData\Local\Temp\ipykernel_17300\1041452492.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('select country_name, region_name from countries join regions using (region_id)',conn)
#                 country_name             region_name
# 0                    Belgium                  Europe
# 1                Switzerland                  Europe
# 2                    Germany                  Europe
# 3                    Denmark                  Europe
# 4                     France                  Europe
# 5                      Italy                  Europe
# 6                Netherlands                  Europe
# 7             United Kingdom                  Europe
# 8                  Argentina                Americas
# 9                     Brazil                Americas
# ...

# %%
#task 2

# %%
d1=pd.read_sql_query('select * from employees' , conn)
d2=pd.read_sql_query('select * from departments' , conn)
d3=pd.read_sql_query('select * from countries ' ,conn)
d4=pd.read_sql_query(' select * from locations ' ,conn)
# Out:
# C:\Users\Rasireddy Theja\AppData\Local\Temp\ipykernel_17300\3016104188.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d1=pd.read_sql_query('select * from employees' , conn)
# C:\Users\Rasireddy Theja\AppData\Local\Temp\ipykernel_17300\3016104188.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d2=pd.read_sql_query('select * from departments' , conn)
# C:\Users\Rasireddy Theja\AppData\Local\Temp\ipykernel_17300\3016104188.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
d1.columns
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'email', 'phone_number',
#        'hire_date', 'job_id', 'salary', 'commission_pct', 'manager_id',
#        'department_id'],
#       dtype='object')

# %%
d2.columns
# Out:
# Index(['department_id', 'department_name', 'manager_id', 'location_id'], dtype='object')

# %%
m1=pd.merge(d1,d2,on='department_id')

# %%
m1
# Out:
#      employee_id first_name last_name     email    phone_number   hire_date  \
# 0            100     Steven      King     SKING    515.123.4567  1987-06-17
# 1            101      Neena   Kochhar  NKOCHHAR    515.123.4568  1989-09-21
# 2            102        Lex   De Haan   LDEHAAN    515.123.4569  1993-01-13
# 3            103  Alexander    Hunold   AHUNOLD    590.423.4567  1990-01-03
# 4            104      Bruce     Ernst    BERNST    590.423.4568  1991-05-21
# ..           ...        ...       ...       ...             ...         ...
# 101          202        Pat       Fay      PFAY    603.123.6666  1997-08-17
# 102          203      Susan    Mavris   SMAVRIS    515.123.7777  1994-06-07
# 103          204    Hermann      Baer     HBAER    515.123.8888  1994-06-07
# 104          205    Shelley   Higgins  SHIGGINS    515.123.8080  1994-06-07
# 105          206    William     Gietz    WGIETZ  51hr5.123.8181  1994-06-07
#
# ...

# %%
d4.columns
# Out:
# Index(['location_id', 'street_address', 'postal_code', 'city',
#        'state_province', 'country_id'],
#       dtype='object')

# %%
m2=pd.merge(m1,d4,on='location_id')
final_df=pd.merge(m2,d3,on='country_id')

# %%
final_df
# Out:
#      employee_id first_name  last_name     email        phone_number  \
# 0            100     Steven       King     SKING        515.123.4567
# 1            101      Neena    Kochhar  NKOCHHAR        515.123.4568
# 2            102        Lex    De Haan   LDEHAAN        515.123.4569
# 3            108      Nancy  Greenberg  NGREENBE        515.124.4569
# 4            109     Daniel     Faviet   DFAVIET        515.124.4169
# ..           ...        ...        ...       ...                 ...
# 101          179    Charles    Johnson  CJOHNSON  011.44.1644.429262
# 102          203      Susan     Mavris   SMAVRIS        515.123.7777
# 103          201    Michael  Hartstein  MHARTSTE        515.123.5555
# 104          202        Pat        Fay      PFAY        603.123.6666
# 105          204    Hermann       Baer     HBAER        515.123.8888
#
#       hire_date      job_id   salary  commission_pct  manager_id_x  ...  \
# ...

# %%
final_df.columns
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'email', 'phone_number',
#        'hire_date', 'job_id', 'salary', 'commission_pct', 'manager_id_x',
#        'department_id', 'department_name', 'manager_id_y', 'location_id',
#        'street_address', 'postal_code', 'city', 'state_province', 'country_id',
#        'country_name', 'region_id'],
#       dtype='object')

# %%
final_df['country_name'].value_counts().to_frame().reset_index()
# Out:
#                country_name  count
# 0  United States of America     68
# 1            United Kingdom     35
# 2                    Canada      2
# 3                   Germany      1

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('mysql+pymysql://root:root123@localhost/hr')

# %%
final_df.to_sql('Employee_count2',engine,index=False)
# Out:
# C:\Users\Rasireddy Theja\AppData\Local\Temp\ipykernel_17300\1097085680.py:1: UserWarning: The provided table name 'Employee_count2' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   final_df.to_sql('Employee_count2',engine,index=False)
# 106
